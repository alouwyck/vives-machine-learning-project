# %% [markdown]
# <a href="https://colab.research.google.com/github/alouwyck/vives-machine-learning-project/blob/main/part_1/1_ML_Project_Politiecontroles_Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="data:image/png;base64,..." align="right" /><br>
#
#
# **MACHINE LEARNING FUNDAMENTALS**<br>
# Academiejaar 2023-2024<br>
# Andy Louwyck
#
# ---
#
#
#
# ---

# %% [markdown]
# # **Project Politiecontroles: Data Preparation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In dit project gaan we gebruik maken van een dataset met politiedata. Die dataset gaan we ook koppelen met weerdata. De datasets zijn ook terug te vinden op [Kaggle](https://www.kaggle.com/), een online community voor data scientist en machine learning engineers, waar je heel veel andere datasets en notebooks terugvindt. Kaggle is ook heel bekend voor zijn competities.
#
# In een eerste fase van het project gaan we de data opkuisen en klaarmaken voor de volgende fasen. Deze fase heet de **data preparation**. We gaan terwijl ook een eenvoudige data analyse uitvoeren. Deel 1 van de notebook is in feite een examen Python binnen een opleiding Data Scientist of Data Analist aan een erkend opleidingscentrum. Het oplossen van dit examen zal je helpen om vertrouwd te geraken met de data.
#
# Het is bovendien een uitstekende oefening op het gebruik van de Pandas library! Maak daarom zo weinig mogelijk gebruik van for-lussen en pas in de plaats daarvan Pandas functies en methodes toe! Probeer dit deel binnen 3 uren op te lossen. Je mag internet en AI tools zoals ChatGPT gebruiken. Dat laatste is zelfs sterk aan te raden als je je efficiëntie wil verhogen!
#
# In deel 2 van de notebook gaan we de data verder prepareren om er in een volgende fase machine learning op toe te kunnen passen.

# %% [markdown]
# ## Deel 1

# %% [markdown]
# De bedoeling van het examen is om een kleine analyse te doen rond 1 bepaald onderwerp. De dataset `'police.csv'` bevat data over verkeerscontroles in de staat Rhode Island van de VS. De dataset `'weather.csv'` bevat data over het weer op een bepaalde dag in die staat.

# %% [markdown]
# Vooraleer je kan starten aan de echte analyse, moet je natuurlijk weten wat er in je dataset zit. In een eerste stap gaan we de data opkuisen: overbodige kolommen verwijderen, wat met lege waarden, correcte datatypes, ...

# %% [markdown]
# Begin eerst met `"police.csv"` correct als Pandas `DataFrame` in te lezen.

# %% [markdown]
# Ga na wat er in de DataFrame zit: welke kolommen, inzicht in de waarden in die kolommen, ... Gebruik DataFrame methode `info()`.

# %% [markdown]
# Zijn er missing values in bepaalde kolommen? Hoeveel?

# %% [markdown]
# Hoeveel rijen en kolommen zijn er?

# %% [markdown]
# Er mag een kolom met zekerheid verwijderd worden. Welke en waarom? Verwijder deze kolom!

# %% [markdown]
# Tel het aantal unieke waarden in elke kolom. Hou er rekening mee dat er `NaN` of `NA` waarden in de data aanwezig zijn! Zijn er kolommen die slechts één waarde bevatten? Zo ja, verwijder die kolom.

# %% [markdown]
# Aangezien onze uiteindelijke analyse gaat over de relatie tussen het gender van de bestuurder en de verkeerscontroles, beslissen we om de `NaN` values uit `'driver_gender'` te verwijderen. Tel als controle opnieuw het aantal `NaN` waarden in deze kolom. Maak geen gebruik van een `for`-lus, maar van boolean indexing!

# %% [markdown]
# Ga na of er duplicate data in onze DataFrame zit.

# %% [markdown]
# Verwijder vervolgens de volledige duplicaten. Maak opnieuw gebruik van boolean indexing.

# %% [markdown]
# Controleer nu de datatypes van de kolommen.

# %% [markdown]
# Kijk vooral naar de inhoud van de `'is_arrested'` en het datatype dat eraan gegeven wordt.

# %% [markdown]
# Verander het datatype van `'is_arrested'` naar boolean. Controleer nu enkel het datatype van `'is_arrested'` om te zien of het type correct is.

# %% [markdown]
# We willen graag `'stop_date'` en `'stop_time'` combineren tot 1 kolom. Hiervoor gaan we eerst die twee kolommen samenvoegen waarbij we de datum en tijd scheiden door een spatie. Daarna converteren we naar `datetime` en we slaan het resultaat op in een nieuwe kolom `'stop_datetime'`. We controleren hierna nogmaals de datatypes om te zien of dit gelukt is!

# %% [markdown]
# ### Gender vs politiegedrag: analyse

# %% [markdown]
# Nu gaan we echt aan de slag: heeft het gender van de bestuurder een effect op het gedrag van de politie?

# %% [markdown]
# Eerst gaan we kijken naar de overtredingen per gender. Tel het aantal waarden in `'violation'`.

# %% [markdown]
#  Druk nu die aantallen uit als proportie van het totaal.

# %% [markdown]
# Maak nu een nieuwe DataFrame aan waarin enkel de vrouwelijke bestuurders (`"F"`) zitten. Maak ook hier gebruik van boolean indexing!

# %% [markdown]
# Doe nu hetzelfde, maar nu voor de mannelijke bestuurders (`"M"`).

# %% [markdown]
# Bereken nu proportioneel het aantal overtredingen in de DataFrame met vrouwelijke bestuuders.

# %% [markdown]
# Bereken ook de proporties voor de mannelijke bestuurders.

# %% [markdown]
# Vergelijk nu de snelheidsovertredingen tussen beide genders. Maak een DataFrame aan voor vrouwen die als overtreding te snel gereden hebben (`"Speeding"`).

# %% [markdown]
# Doe opnieuw hetzelfde voor de mannen.

# %% [markdown]
# Bereken vervolgens proportioneel de uitkomst `'stop_outcome'`. Doe dit voor beide subdatasets die we hierboven aanmaakten. Zo kunnen we vergelijken of er een verschil in resultaat is bij mannen en vrouwen die een snelheidsovertreding begaan.

# %% [markdown]
# Vervolgens gaan we kijken naar de variabele `'search_conducted'`. Deze geeft aan of er een zoekactie werd uitgevoerd. Het is een boolean. Tel voor `True` en `False` proportioneel hoeveel zoekacties er al dan niet werden uitgevoerd.

# %% [markdown]
# Het ziet ernaar uit dat er in ongeveer 3,8% van de gevallen een zoekactie werd uitgevoerd. Aangezien we met een boolean waarde zitten, kunnen we het proportioneel aantal `True` waarden eenvoudig berekenen adhv het gemiddelde. Test dit eens uit.

# %% [markdown]
# Wederom willen we kijken of er een verschil is tussen mannen en vrouwen. Verschilt dit per gender?

# %% [markdown]
# Bereken eerst voor het 'vrouwelijke' DataFrame het gemiddeld aantal uitgevoerde zoekacties.

# %% [markdown]
# Bereken hetzelfde voor ons 'mannelijke' DataFrame.

# %% [markdown]
# Bereken dit nu voor mannen en vrouwen simultaan. Maak gebruik van de originele DataFrame en bereken het gemiddeld aantal uitgevoerde zoekacties per gender!

# %% [markdown]
# Het ziet ernaar uit dat mannelijke bestuurders 2x zoveel onderworpen worden aan een zoekactie. Hoe zou dit komen? Misschien is er nog een andere factor die een invloed heeft...
#
# Breid nu je berekening van hierboven uit, en bekijk het gemiddeld aantal zoekacties voor mannen en vrouwen en voor het soort overtreding. Groepeer maw op 2 variabelen.

# %% [markdown]
# Doe nu hetzelfde, maar groepeer eerst op overtreding en daarna pas op gender.

# %% [markdown]
# **Conclusie:** Voor alle types overtredingen is het aantal zoekacties proportioneel hoger voor mannen als voor vrouwen.
#
# Visualiseer dit door een staafdiagram te plotten die het gemiddeld aantal zoekacties toont voor elke soort overtreding en een onderscheid maakt tussen mannelijke en vrouwelijke bestuurders. Laat de categorie `'Other'` violations achterwege.

# %% [markdown]
# ### Gender vs politiegedrag: visuele analyse

# %% [markdown]
# Vervolgens gaan we visueel onze analyse verderzetten.

# %% [markdown]
# Ga na of je op een bepaald uur een grotere kans hebt om gearresteerd te worden. Bereken hiervoor eerst het gemiddeld aantal arrestaties. Gebruik hiervoor kolom `'is_arrested'`.

# %% [markdown]
# Bereken nu het gemiddeld aantal arrestaties per uur en sla dit op in een nieuwe variabele. Je zal module `datetime` nodig hebben om het uur (hour) uit `'stop_datetime'` te halen.

# %% [markdown]
# Gebruik matplotlib om een lijngrafiek te maken voor je nieuw aangemaakte variabele:
# - label voor de x-as: Hour
# - label voor de y-as: Arrests
# - titel: Average number of arrests per hour

# %% [markdown]
# **Conclusie:** Er zijn duidelijk meer arrestaties 's nachts, met een drop in de vroege uurtjes!

# %% [markdown]
# ### Invloed van het weer: analyse

# %% [markdown]
# Als laatste gaan we na of het weer een invloed heeft op onze verkeersdata.

# %% [markdown]
# Laad eerst `'weather.csv'` in een nieuw Pandas DataFrame en bekijk wat erin zit.

# %% [markdown]
# Bekijk de dataset en beschrijf de statistieken van de kolommen met temperaturen adhv methode `describe`: `'TMIN'`, `'TAVG'`, `'TMAX'`. Merk op dat de temperatuur in graden Fahrenheit staat. Zet die dus eerst om naar graden Celsius. Je hoeft hier geen `for`-lus voor toe te passen!

# %% [markdown]
# Maak een nieuwe kolom `'TDIFF'` aan dat het verschil is tussen `'TMAX'` en `'TMIN'`. Ook hiervoor heb je geen `for`-lus nodig!

# %% [markdown]
# Maak een histogram met 20 `bins` om deze nieuwe kolom `'TDIFF'` te visualiseren.

# %% [markdown]
# **Conclusie:** Er zijn geen negatieve waarden en we krijgen een vrij normale distributie. Dat zijn signalen dat deze data te vertrouwen zijn.

# %% [markdown]
# Vervolgens gaan we onze weerdata samenvoegen met onze politiedata. Maak een beperkte dataset aan obv onze weerdata: behoud enkel `'DATE'` en `'rating'`. Bekijk wat hierin zit.

# %% [markdown]
# Wat zijn de unieke waarden in kolom `'rating'`?

# %% [markdown]
# Merge nu de politiedata met deze pas aangemaakte weerrating data op basis van `'stop_date'`. Zorg ervoor dat alle politiedata behouden blijven, ook al is er geen match met onze weerdata!

# %% [markdown]
# Heeft het weer effect op het aantal arrestaties? Eerst bereken je het gemiddeld aantal arrestaties (zie hierboven: dit heb je reeds gedaan!)

# %% [markdown]
# Daarna bereken je het gemiddeld aantal arrestaties per `'rating'`. De rating is een categorische variabele die per dag aangeeft hoe goed of slecht het weer was.

# %% [markdown]
# Als laatste voeg je het type overtreding (`'violation'`) toe als tweede factor in je analyse. Groepeer eerst op overtreding en dan op de rating van het weer.

# %% [markdown]
# **Conclusie:** Er zijn gemiddeld meer arrestaties als het weer slechter wordt, ook over de verschillende types overtredingen.

# %% [markdown]
# Sla het gemiddeld aantal arrestaties per overtreding en rating op als een nieuwe variabele. Dus je kent het DataFrame uit de vorige stap toe aan een variabele.

# %% [markdown]
# Gebruik nu deze nieuwe variabele om enkel het gemiddeld aantal arrestaties te tonen voor een `'Moving violation'` wanneer het weer `'bad'` is.

# %% [markdown]
# Print tenslotte het gemiddeld aantal arrestaties voor een snelheidsovertreding (`"Speeding"`) voor alle 3 de weersomstandigheden.

# %% [markdown]
# Hier stopt het eerste deel dat dus overeenkomt met een examen Python binnen een opleiding tot Data Scientist. Is dat allemaal binnen de drie uren gelukt? Mooi zo! Dan zou je met vlag en wimpel geslaagd zijn!

# %% [markdown]
# ## Deel 2

# %% [markdown]
# In dit tweede deel gaan we de data verder opkuisen om dan tot een finale dataset te komen waarop we machine learning algoritmen kunnen toepassen die we in de lessen hebben gezien.

# %% [markdown]
# Verwijder de `'DATE'` kolom uit het samengevoegde DataFrame en voeg de kolommen `'TMIN'`, `'TMAX'`, `'AWND'` en `'WSF2'` toe. Doe dit zoals je hierboven hebt gedaan o.b.v. kolom `'stop_date'`. Zorg er opnieuw voor dat er geen rijen verdwijnen uit het DataFrame met politie- en weerdata. Check dit!

# %% [markdown]
# Check de statistieken van die 4 nieuwe kolommen die je zopas hebt toegevoegd. Gebruik hiervoor methode `describe()`. Zie je geen verdachte zaken?

# %% [markdown]
# Hoeveel missing values zijn er in kolom '`driver_age`'?

# %% [markdown]
# Die missing values kunnen we eenvoudig vervangen door het geboortejaar van de bestuurder opgeslagen in kolom `'driver_age_raw'` af te trekken van het jaartal van de `'stop_date'`. We creëren daarom eerst een kolom `'year'` die dat jaartal bevat. Ga na welke unieke jaartallen in die nieuwe kolom zitten.

# %% [markdown]
# In kolom `'driver_age_raw'` hebben we nog enkele problemen. Pas nog eens de `describe()` methode toe op deze kolom en dan zie je dat er waarden in die kolom zitten die niet overeenkomen met jaartallen.

# %% [markdown]
# Soms zet men ontbrekende of onbekende waarden ook wel eens gelijk aan nul, wat niet zo'n goed idee is natuurlijk. Wellicht zal dat hier ook het geval zijn, en dus gaan we die nullen vervangen door `NaN`.

# %% [markdown]
# Zijn er nu nog waarden kleiner dan 1900? Ja, er is nog één waarde gelijk aan 1887. Check dat en vervang dat getal door 1987, want we kunnen er hier inderdaad vanuit gaan dat dit een tikfoutje is.

# %% [markdown]
# Er zijn ook nog enkele waarden die onrealistisch groot zijn. Over welke getallen gaat het? Check dit door alle getallen groter dan 2020 te geven! Deze waarden zijn duidelijk fout en zullen we door `NaN` vervangen.

# %% [markdown]
# Check de minimum en maximum leeftijd in kolom `'driver_age'`, want we willen niet buiten dat interval gaan. Sla die waarden op in variabelen. Doe dat ook voor de gemiddelde leeftijd.

# %% [markdown]
# We kunnen nu eenvoudig de ontbrekende leeftijden in kolom `'driver_age'` berekenen door het verschil te nemen van `'year'` en `'driver_age_raw'`. Pas hiervoor boolean indexing toe!

# %% [markdown]
# Zijn er nu nog ontbrekende leeftijden? Zo ja, vul die dan op met het gemiddelde van alle gekende leeftijden. Vergeet niet dat een leeftijd een geheel getal is! Dit vervangen van `NaN`-waarden noemt men **data imputation**: het 'toedichten' of opvullen van ontbrekende waarden.
#
# Doe hetzelfde met zogenaamde *outliers*: leeftijden die buiten het oorspronkelijke leeftijdsinterval vallen en hier wellicht wijzen op een fout.

# %% [markdown]
# Check nu ter controle nog eens de statistieken m.b.v. methode `describe()` en plot een histogram van de leeftijden. Ziet dat er ok uit?

# %% [markdown]
# Naast het uur en het jaar van de `stop_date` is het ook nuttig om de maand en de dag in een aparte kolom te stoppen. De maand geven we weer met de naam: January, February, ... Voor de dag nemen we ook de naam: Monday, Tuesday, ... Check ook altijd het resultaat door de unieke waarden in de nieuwe kolom op te vragen.

# %% [markdown]
# We kunnen nu alle oorspronkelijke kolommen verwijderen die verwijzen naar de datum en het tijdstip waarop de controles werden uitgevoerd: `"stop_date"`, `"stop_time"`, `"stop_datetime"` en `"DATE"`. Ook kolom `"driver_age_raw"` hebben we niet meer nodig, net als kolom `"violation_raw"`.

# %% [markdown]
# Check nu nog eens of er nog kolommen met ontbrekende waarden zijn. Kolommen met missing values mag je ook verwijderen.

# %% [markdown]
# We hebben de waarden in kolom `'stop_duration'` nog niet gecontroleerd. Vraag de unieke waarden en bijhorende aantallen op van die kolom.

# %% [markdown]
# Er komt dus één keer een waarde `'1'` en een waarde `'2'` voor. Vraag die records op. Je ziet dat in het geval van de `'1'` het wellicht om een duur van `'0-15 Min'` gaat. Vervang daarom de `'1'` door die duur. In het geval van de `'2'` gaat het om een arrestatie, dus daar gaan we een `'30+ Min'` van maken. Check na het vervangen van die 2 waarden opnieuw de aantallen!

# %% [markdown]
# Herschik nu de kolommen in het DataFrame zodat ze in deze volgorde voorkomen:
#
# ```python
# columns = ['year', 'month', 'day', 'hour',
#            'driver_gender', 'driver_age', 'driver_race',
#            'violation', 'search_conducted', 'stop_outcome', 'is_arrested', 'stop_duration', 'drugs_related_stop',
#            'rating', 'TMIN', 'TMAX', 'AWND', 'WSF2']
# ```

# %% [markdown]
# Hernoem kolom `'rating'` als `'weather'`.

# %% [markdown]
# Bewaar het DataFrame tenslotte als `"police_controls.csv"`. Zorg ervoor dat de index niet mee wordt opgeslagen!

# %% [markdown]
# In de volgende fasen gaan we met die opgekuiste dataset werken. Vergeet dus niet om de csv-file te downloaden of weg te schrijven naar je Google Drive!

# %% [markdown]
# ---
